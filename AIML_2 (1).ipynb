# %%
# !pip install pandas

# %%
people = ["vikas","kaju","sujith","pandu"]
age = [18,19,20,21]
height = [154,154,174,142]
weight = [45,45,74,42]

# %%
data = {
    'Name' : people,
    'age' : age,
    'height' : height,
    'weight' : weight
}
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  age  height  weight
# 0   vikas   18     154      45
# 1    kaju   19     154      45
# 2  sujith   20     174      74
# 3   pandu   21     142      42

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(df['age'],df['weight'],color='blue',marker ='o')
plt.title('scatter plot of age vs weight')
plt.xlabel('age(yeras)')
plt.ylabel('weight(kg)')
plt.grid(True)
plt.show()

# %%
#scatter plot:age vs weight
plt.figure(figsize=(8,6))
plt.hist(df['age'],bins=8,color='orange')
plt.title('scatter plot of age vs weight')
plt.xlabel('age(yeras)')
plt.ylabel('weight(kg)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.bar(df['Name'],df['height'],color='orange')
plt.title('bar chart of individuals\height')
plt.xlabel('name')
plt.ylabel('height')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(df['Name'],bins=5,color='orange',edgecolor='black' )
plt.title('histogram of age distribution')
plt.xlabel('age (year)')
plt.ylabel('frequency')
plt.show()
